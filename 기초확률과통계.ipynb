# %%
# 📌 통계_coding연습 (3주차)
# 5개 연습 예제를 하나의 Colab 노트북으로 정리

# 공통 라이브러리
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import font_manager as fm

# -----------------------------------
# 연습01: 체중 측정 데이터 선 그래프
# -----------------------------------
x = np.array([1, 2, 3, 4, 5, 6, 7])  # 날짜
y = np.array([78.4, 78.6, 78.5, 78.9, 78.2, 79.4, 78.6])  # 체중 데이터

plt.plot(x, y, color="r")
plt.xlabel("Day")
plt.ylabel("Weight")
plt.title("연습01: 선 그래프")
plt.show()

# -----------------------------------
# 연습02: 체중 측정 데이터 산점도
# -----------------------------------
plt.scatter(x, y, color="r")
plt.xlabel("Day")
plt.ylabel("Weight")
plt.title("연습02: 산점도")
plt.show()

# -----------------------------------
# 연습03: grid() 적용 (선+마커)
# -----------------------------------
plt.plot(x, y, color="r", marker="o")
plt.grid()
plt.xlabel("Day")
plt.ylabel("Weight")
plt.title("연습03: grid() 적용")
plt.show()

# -----------------------------------
# 연습04: np.linspace + 두 개의 함수 그래프
# -----------------------------------
x2 = np.linspace(-5, 5, 300)  # -5에서 5까지 300 구간
y1 = x2**2
y2 = (x2 - 2)**2

plt.plot(x2, y1, color="r", label="y1 = x^2")
plt.plot(x2, y2, color="k", linestyle="--", label="y2 = (x-2)^2")
plt.grid()
plt.legend()
plt.title("연습04: np.linspace 예제")
plt.show()

# -----------------------------------
# 연습05: 그래프 모양 꾸미기 (한글 폰트/범례/축/그리드)
# -----------------------------------
# (Colab 전용) 나눔고딕 설치: Colab이면 주석 해제 후 실행
# !apt-get update -qq
# !apt-get install -y fonts-nanum

font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
if os.path.exists(font_path):
    fm.fontManager.addfont(font_path)
    plt.rc("font", family=fm.FontProperties(fname=font_path).get_name())
plt.rcParams["axes.unicode_minus"] = False  # 마이너스 깨짐 방지

x3 = np.linspace(-5, 5)
y3 = 2 * x3
y4 = 5 * x3

plt.plot(x3, y3, label="y1 값", color="r")                     # 빨간 선
plt.plot(x3, y4, label="y2 값", linestyle="dashed", color="k")  # 검정 점선
plt.xlabel("X-축", size=14)
plt.ylabel("Y-축", size=14)
plt.title("그래프 제목")
plt.grid()
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
# ...
